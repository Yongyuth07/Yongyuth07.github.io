# %%
MY_SECRET_KEY=""

# %%
# !pip install ultralytics
# !pip install roboflow

# %%
import ultralytics
from roboflow import Roboflow
from ultralytics import YOLO
from IPython.display import Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
rf = Roboflow(api_key="guHl7IfscCvbhcGMBXfR")
project = rf.workspace("-jwzpw").project("continuous_fire")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to continuous_fire-1 in yolov8:: 100%|██████████| 3492/3492 [00:00<00:00, 6640.26it/s]

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/continuous_fire-1/data.yaml epochs=1 imgsz=640 plots=True
# Out:
# Ultralytics 8.3.68 🚀 Python-3.11.11 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# VIEW MODEL TRANING CHARTS
Image(filename=f'/content/runs/detect/train6/results.png', width=600)
